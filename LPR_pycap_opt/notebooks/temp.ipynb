# %%
from pathlib import Path

files = [
    "LPR_redux/LPR_pycap_opt/pycap_runs/pycap_pest/run_depletion_q_baseline_0.0_1.0_0.01/depletion_q_baseline_0.0_1.0_0.01.pareto.archive.summary.csv.zip",
    "LPR_redux/LPR_pycap_opt/pycap_runs/pycap_pest/run_depletion_q_Tmin10per_0.0_1.0_0.01/depletion_q_Tmin10per_0.0_1.0_0.01.pareto.archive.summary.csv.zip",
    "LPR_redux/LPR_pycap_opt/pycap_runs/pycap_pest/run_depletion_q_baseline_0.0_1.0_0.01/depletion_q_Tplus10per_0.0_1.0_0.01.pareto.archive.summary.csv.zip",
]

for f in files:
    p = Path(f)
    print("\n", p)
    print("exists:", p.exists())
    if p.exists():
        df = pd.read_csv(p)
        print("shape:", df.shape)
        print("columns:", list(df.columns[:40]))
# Out:
#  LPR_redux/LPR_pycap_opt/pycap_runs/pycap_pest/run_depletion_q_baseline_0.0_1.0_0.01/depletion_q_baseline_0.0_1.0_0.01.pareto.archive.summary.csv.zip
# exists: False
#
#  LPR_redux/LPR_pycap_opt/pycap_runs/pycap_pest/run_depletion_q_Tmin10per_0.0_1.0_0.01/depletion_q_Tmin10per_0.0_1.0_0.01.pareto.archive.summary.csv.zip
# exists: False
#
#  LPR_redux/LPR_pycap_opt/pycap_runs/pycap_pest/run_depletion_q_baseline_0.0_1.0_0.01/depletion_q_Tplus10per_0.0_1.0_0.01.pareto.archive.summary.csv.zip
# exists: False
