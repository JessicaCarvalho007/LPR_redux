# %%
from pathlib import Path
import pandas as pd

files = [
    "/workspaces/LPR_redux/LPR_pycap_opt/pycap_runs/pycap_pest/run_depletion_q_baseline_0.0_1.0_0.01/depletion_q_baseline_0.0_1.0_0.01.pareto.archive.summary.csv.zip",
    "/workspaces/LPR_redux/LPR_pycap_opt/pycap_runs/pycap_pest/run_depletion_q_Tmin10per_0.0_1.0_0.01/depletion_q_Tmin10per_0.0_1.0_0.01.pareto.archive.summary.csv.zip",
    "/workspaces/LPR_redux/LPR_pycap_opt/pycap_runs/pycap_pest/run_depletion_q_Tplus10per_0.0_1.0_0.01/depletion_q_Tplus10per_0.0_1.0_0.01.pareto.archive.summary.csv.zip",
]

for f in files:
    p = Path(f)
    print("\n", p)
    print("exists:", p.exists())
    if p.exists():
        df = pd.read_csv(p)
        print("shape:", df.shape)
        print("columns:", list(df.columns[:40]))
# Out:
#  /workspaces/LPR_redux/LPR_pycap_opt/pycap_runs/pycap_pest/run_depletion_q_baseline_0.0_1.0_0.01/depletion_q_baseline_0.0_1.0_0.01.pareto.archive.summary.csv.zip
# exists: True
# shape: (8809, 10)
# columns: ['generation', 'member', 'lpr:total_combined:bdpl', 'obj_well', 'nsga2_front', 'nsga2_crowding_distance', 'spea2_unconstrained_fitness', 'spea2_constrained_fitness', 'is_feasible', 'feasible_distance']
#
#  /workspaces/LPR_redux/LPR_pycap_opt/pycap_runs/pycap_pest/run_depletion_q_Tmin10per_0.0_1.0_0.01/depletion_q_Tmin10per_0.0_1.0_0.01.pareto.archive.summary.csv.zip
# exists: True
# shape: (9487, 10)
# columns: ['generation', 'member', 'lpr:total_combined:bdpl', 'obj_well', 'nsga2_front', 'nsga2_crowding_distance', 'spea2_unconstrained_fitness', 'spea2_constrained_fitness', 'is_feasible', 'feasible_distance']
#
#  /workspaces/LPR_redux/LPR_pycap_opt/pycap_runs/pycap_pest/run_depletion_q_Tplus10per_0.0_1.0_0.01/depletion_q_Tplus10per_0.0_1.0_0.01.pareto.archive.summary.csv.zip
# ...
