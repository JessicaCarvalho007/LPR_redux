# %% [markdown]
# # PyCap runs for Little Plover River - based on Wisconsin DNR strategy

# %% [markdown]
# This notebook allows you to update pumping rates in the input Excel file, make a run, and return all the metrics. This script will convert that `.xlsx` file into a `.yml`.

# %%
import yaml
import pandas as pd
import numpy as np
from pathlib import Path
import sys
sys.path.append('../scripts')
from wdnr_pycap import Excel2YML, pycap_metrics
import matplotlib.pyplot as plt
import os, platform
from pycap.analysis_project import Project
import geopandas as gpd
from shapely.geometry import Point
from  datetime import date

# %%
pycap_run_path = Path("../pycap_runs")

background_run_path = pycap_run_path / 'pycap_base'

# %% [markdown]
# ### Make a map showing all the well locations and pumping rates - you can use this to guide your scenario creation

# %%
GPM2CFS = 1/7.48052/60
with open(background_run_path / "LPR_Redux.yml", "r") as ifp:
    indat = yaml.safe_load(ifp)
indcol = [i for i in indat.keys() if 'well' in i.lower()]
names = [indat[i]['name'] for i in indcol]
locs = [Point(-indat[i]['loc']['x'],indat[i]['loc']['y']) for i in indcol]
Q = [indat[i]['Q'] for i in indcol]

wells_gdf = gpd.GeoDataFrame(index = indcol, data={"name":names, 
                                                   "Q_gpm":Q, 
                                                   "Q_cfs": [Qi*GPM2CFS for Qi in Q],
                                                   "geometry":locs}, crs=4326)
wells_gdf.explore(                  
                vmin=0,vmax=1,
                  style_kwds={"style_function":
                                  lambda x: 
                                  {"radius":x["properties"]["Q_gpm"]/20}})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c01ba6da19a7d9f764cbae59c86b771 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c01ba6da19a7d9f764cbae59c86b771&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c01ba6da19a7d9f764cbae59c86b771 = L.map(
#                 &quot;map_0c01ba6da19a7d9f764cbae59c86b771&quot;,
#                 {
#                     center: [44.48916415, -89.43102300000001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_0c01ba6da19a7d9f764cbae59c86b771);
#
#
#
#
#
#             var tile_layer_f91026c0fcade982f36f6167cbf8549f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f91026c0fcade982f36f6167cbf8549f.addTo(map_0c01ba6da19a7d9f764cbae59c86b771);
#
#
#             map_0c01ba6da19a7d9f764cbae59c86b771.fitBounds(
#                 [[44.3828, -89.574306], [44.5955283, -89.28774]],
#                 {}
#             );
#
#
#         function geo_json_cca164a262c84f568b2757aee6505b90_styler(feature) {
#             switch(feature.id) {
#                 case &quot;well_418&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 5.475, &quot;weight&quot;: 2};
#                 case &quot;well_466&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 15.794999999999998, &quot;weight&quot;: 2};
#                 case &quot;well_467&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 14.844999999999999, &quot;weight&quot;: 2};
#                 case &quot;well_490&quot;: case &quot;well_24249&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 1.385, &quot;weight&quot;: 2};
#                 case &quot;well_509&quot;: case &quot;well_67895&quot;: case &quot;well_68216&quot;: case &quot;well_68218&quot;: case &quot;well_73940&quot;: case &quot;well_92714&quot;: case &quot;well_93422&quot;: case &quot;well_93423&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 0.005, &quot;weight&quot;: 2};
#                 case &quot;well_602&quot;: case &quot;well_72756&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 0.025, &quot;weight&quot;: 2};
#                 case &quot;well_603&quot;: case &quot;well_58434&quot;: case &quot;well_68219&quot;: case &quot;well_93424&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 0.01, &quot;weight&quot;: 2};
#                 case &quot;well_798&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 6.779999999999999, &quot;weight&quot;: 2};
#                 case &quot;well_807&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 4.13, &quot;weight&quot;: 2};
#                 case &quot;well_850&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 5.36, &quot;weight&quot;: 2};
#                 case &quot;well_862&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 0.22999999999999998, &quot;weight&quot;: 2};
#                 case &quot;well_1013&quot;: case &quot;well_70186&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 6.255, &quot;weight&quot;: 2};
#                 case &quot;well_1302&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 4.41, &quot;weight&quot;: 2};
#                 case &quot;well_1323&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 3.81, &quot;weight&quot;: 2};
#                 case &quot;well_1486&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 11.14, &quot;weight&quot;: 2};
#                 case &quot;well_1584&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 7.525, &quot;weight&quot;: 2};
#                 case &quot;well_1589&quot;:
#                     return {&quot;fillOpacit

# %% [markdown]
# ### In the Excel file noted below, you can change pumping rates in the `HCW_Inputs` sheet by changing the `Q_gpm` values (this column should be bold and highlighted). Once you update this and save, you can run through this notebook to get results for all the metrics.
#
# ### If you lose track of the original pumping values, you can copy the entire column back from `../Inputs/LPR_Prepped_IDW.xlsx`

# %%
#### Path to excel input file. You can change the name if you want to keep multiple versions of it.
pycap_inputs_excel = Path("../Student_Input/LPR_Single_Run90.xlsx")

# %% [markdown]
# ### NOTE! You should change the `pycap_run_name` variable below to keep track of runs you make. Results will be saved with that name

# %%
pycap_run_name = 'LPR_Single_Run90'

base_run_path = pycap_run_path / 'student_run'

# %%
if not base_run_path.exists():
    base_run_path.mkdir(parents=True)

# %% [markdown]
# ### Create YML from Excel
# ##### Created with a function

# %%
project_dict, stream_dict, well_dict, ddresp_dict, combdict = Excel2YML(pycap_inputs_excel,pycap_run_name, base_run_path)

# %% [markdown]
# ### Now run the base model with `pycap`

# %%
yml_filename = f"{pycap_run_name}.yml"

# %% [markdown]
# #### We create a `Project`, then report the responses and finally write the responses to an external CSV file

# %%
ap = Project(base_run_path /  yml_filename)
ap.report_responses()
ap.write_responses_csv()
# Out:
# Writing report to ../pycap_runs/student_run/LPR_Single_Run90.yml.import_report
#
#
#
# Successfully parsed ../pycap_runs/student_run/LPR_Single_Run90.yml (high five!)
# *************************
# Summary follows:
#
# WELLS:
# 326 existing wells:
# 	466
# 	467
# 	490
# 	509
# 	602
# 	603
# 	798
# 	807
# 	850
# 	862
# 	1013
# 	1302
# 	1323
# 	1486
# 	1584
# 	1589
# 	1643
# 	1683
# 	1860
# 	2544
# 	2750
# 	2886
# 	3473
# 	3949
# 	4171
# 	23610
# 	23611
# 	23618
# 	23620
# 	23627
# 	23629
# 	23630
# 	23631
# 	23635
# 	23637
# 	23638
# 	23639
# 	23645
# 	23646
# 	23648
# 	23653
# 	23695
# 	23697
# 	23698
# 	23699
# 	23700
# 	23709
# 	23710
# 	23715
# 	23716
# 	23720
# 	23721
# 	23722
# 	23723
# 	23726
# 	23727
# 	23728
# 	23729
# 	23751
# 	23752
# 	23753
# 	23754
# 	23755
# 	23756
# 	23757
# 	23758
# 	23770
# 	23776
# 	23778
# 	23781
# 	23790
# 	23791
# 	23794
# 	23795
# 	23798
# 	23800
# 	23807
# 	23816
# 	23818
# 	23820
# 	23823
# 	23836
# 	23837
# 	23846
# 	23847
# 	23848
# 	23851
# 	23864
# 	23865
# 	23866
# 	23867
# 	23868
# 	23869
# 	23870
# 	23876
# 	23881
# 	23883
# 	23886
# 	LPR:1860
# 	LPR:2544
# 	LPR:2750
# 	LPR:2886
# 	LPR:3473
# 	LPR:3949
# 	LPR:4171
# 	LPR:23610
# 	LPR:23611
# 	LPR:23618
# 	LPR:23620
# 	LPR:23627
# 	LPR:23629
# 	LPR:23630
# 	LPR:23631
# 	LPR:23635
# 	LPR:23637
# 	LPR:23638
# 	LPR:23639
# 	LPR:23645
# 	LPR:23646
# 	LPR:23648
# 	LPR:23653
# 	LPR:23695
# 	LPR:23697
# 	LPR:23698
# 	LPR:23699
# 	LPR:23700
# 	LPR:23709
# 	LPR:23710
# 	LPR:23715
# 	LPR:23716
# 	LPR:23720
# 	LPR:23721
# 	LPR:23722
# 	LPR:23723
# 	LPR:23726
# 	LPR:23727
# 	LPR:23728
# 	LPR:23729
# 	LPR:23751
# 	LPR:23752
# 	LPR:23753
# 	LPR:23754
# 	LPR:23755
# 	LPR:23756
# 	LPR:23757
# 	LPR:23758
# 	LPR:23770
# 	LPR:23776
# 	LPR:23778
# 	LPR:23781
# 	LPR:23790
# 	LPR:23791
# 	LPR:23794
# 	LPR:23795
# 	LPR:23798
# 	LPR:23800
# 	LPR:23807
# 	LPR:23816
# 	LPR:23818
# 	LPR:23820
# 	LPR:23823
# 	LPR:23836
# 	LPR:23837
# 	LPR:23846
# 	LPR:23847
# 	LPR:23848
# 	LPR:23851
# 	LPR:23864
# 	LPR:23865
# 	LPR:23866
# 	LPR:23867
# 	LPR:23868
# 	LPR:23869
# 	LPR:23870
# 	LPR:23876
# 	LPR:23881
# 	LPR:23883
# 	LPR:23886
# 	LPR:23888
# 	LPR:23889
# 	LPR:23890
# 	LPR:23895
# 	LPR:23898
# 	LPR:23908
# 	LPR:23909
# 	LPR:23910
# 	LPR:23913
# 	LPR:23915
# 	LPR:23919
# 	LPR:23926
# 	LPR:23928
# 	LPR:23929
# 	LPR:23930
# 	LPR:23934
# 	LPR:23936
# 	LPR:23937
# 	LPR:23939
# 	LPR:23942
# 	LPR:23944
# 	LPR:23948
# 	LPR:23956
# 	LPR:23961
# 	LPR:23962
# 	LPR:23963
# 	LPR:23966
# 	LPR:23967
# 	LPR:23972
# 	LPR:23977
# 	LPR:23978
# 	LPR:23979
# 	LPR:23980
# 	LPR:23981
# 	LPR:23983
# 	LPR:23984
# 	LPR:23985
# 	LPR:23987
# 	LPR:23998
# 	LPR:24003
# 	LPR:24005
# 	LPR:24010
# 	LPR:24011
# 	LPR:24012
# 	LPR:24016
# 	LPR:24024
# 	LPR:24030
# 	LPR:24033
# 	LPR:24036
# 	LPR:24037
# 	LPR:24042
# 	LPR:24043
# 	LPR:24045
# 	LPR:24047
# 	LPR:24049
# 	LPR:24059
# 	LPR:24063
# 	LPR:24066
# 	LPR:24080
# 	LPR:24091
# 	LPR:24093
# 	LPR:24110
# 	LPR:24120
# 	LPR:24121
# 	LPR:24125
# 	LPR:24130
# 	LPR:24135
# 	LPR:24137
# 	LPR:24165
# 	LPR:24166
# 	LPR:24169
# 	LPR:24172
# 	LPR:24195
# 	LPR:24197
# 	LPR:24203
# 	LPR:24216
# 	LPR:24225
# 	LPR:24226
# 	LPR:24227
# 	LPR:24239
# 	LPR:24240
# 	LPR:24247
# 	LPR:24249
# 	LPR:24252
# 	LPR:24253
# 	LPR:24256
# 	LPR:24265
# 	LPR:24266
# 	LPR:24274
# 	LPR:24279
# 	LPR:24283
# 	LPR:24285
# 	LPR:24286
# 	LPR:24291
# 	LPR:24293
# 	LPR:24294
# 	LPR:24302
# 	LPR:24305
# 	LPR:24307
# 	LPR:24311
# 	LPR:24317
# 	LPR:24323
# 	LPR:58403
# 	LPR:58405
# 	LPR:58406
# 	LPR:58407
# 	LPR:58410
# 	LPR:58411
# 	LPR:58414
# 	LPR:58416
# 	LPR:58424
# 	LPR:58433
# 	LPR:58434
# 	LPR:67673
# 	LPR:67895
# 	LPR:68008
# 	LPR:68216
# 	LPR:68218
# 	LPR:68219
# 	LPR:68220
# 	LPR:68221
# 	LPR:68294
# 	LPR:68475
# 	LPR:68529
# 	LPR:68693
# 	LPR:68695
# 	LPR:68872
# 	LPR:68917
# 	LPR:68925
# 	LPR:68926
# 	LPR:69049
# 	LPR:69065
# 	LPR:69282
# 	LPR:69288
# 	LPR:69289
# 	LPR:69480
# 	LPR:69508
# 	LPR:69576
# 	LPR:69635
# 	LPR:69636
# 	LPR:69638
# 	LPR:69669
# 	LPR:69970
# 	LPR:69990
# 	LPR:70119
# 	LPR:70120
# 	LPR:70186
# 	LPR:70191
# 	LPR:70263
# 	LPR:70517
# 	LPR:70519
# 	LPR:70520
# 	LPR:70548
# 	LPR:70881
# 	LPR:70961
# 	LPR:70974
# 	LPR:70975
# 	LPR:71044
# 	LPR:71062
# 	LPR:71063
# 	LPR:71109
# 	LPR:71110
# 	LPR:71117
# 	LPR:71156
# 	LPR:71199
# 	LPR:71495
# 	LPR:71935
# 	LPR:71998
# 	LPR:72082
# 	LPR:72094
# 	LPR:72095
# 	LPR:72269
# 	LPR:72301
# 	LPR:72304
# 	LPR:72421
# 	LPR:72422
# 	LPR:72436
# 	LPR:72437
# 	LPR:72607
# 	LPR:72610
# 	LPR:72713
# 	LPR:72756
# 	LPR:72983
# 	LPR:73153
# 	LPR:73262
# 	LPR:73280
# 	LPR:73281
# 	LPR:73372
# 	LPR:73440
# 	LPR:73481
# 	LPR:73715
# 	LPR:73737
# 	LPR:73761
# 	LPR:73762
# 	LPR:73906
# 	LPR:73940
# 	LPR:73942
# 	LPR:74131
# 	LPR:74280
# 	LPR:84404
# 	LPR:84409
# 	LPR:84411
# 	LPR:91103
# 	LPR:91173
# 	LPR:91808
# 	LPR:91996
# 	LPR:91997
# 	LPR:92099
# 	LPR:92184
# 	LPR:92299
# 	LPR:92696
# 	LPR:92714
# 	LPR:92724
# 	LPR:92743
# 	LPR:92808
# 	LPR:92885
# 	LPR:92981
# 	LPR:93142
# 	LPR:93143
# 	LPR:93349
# 	LPR:93422
# 	LPR:93423
# 	LPR:93424
# 	LPR:93469
# 	LPR:93832
# 	LPR:94302
# 	LPR:94988
# 	LPR:95068
# DRAWDOWN RESPONSES:
# 	LakeEmily

# %% [markdown]
# #### Now let's have a look at the main results files
# ##### First the summary base depletion

# %%
depl = pd.read_csv(
    base_run_path / f"output/{pycap_run_name}.table_report.base_stream_depletion.csv", index_col = 0
)
depl
# Out:
#                          LPR
# 418             6.689931e-04
# 466             3.830911e-02
# 467             2.874797e-02
# 490             5.003177e-12
# 509             2.753485e-07
# ...                      ...
# 94988           2.480979e-08
# 95068           7.244530e-06
# total_proposed  6.689931e-04
# total_existing  5.299346e-01
# total_combined  5.305181e-01
#
# [330 rows x 1 columns]

# %%
all_time_series = pd.read_csv(
    base_run_path / f"output/{pycap_run_name}.table_report.all_ts.csv".format(pycap_run_name), index_col=0
)

cum_depl = all_time_series.sum(axis=1)

fig,ax = plt.subplots(nrows=1, ncols=1)
ax.plot(all_time_series, alpha=0.6, c='k', lw=0.2)
ax.plot(cum_depl, c='r')
ax.set_title('Cumulative Depl, LPR at Hoover,Base Case Analysis')
ax.set_xlabel("Days")
ax.set_ylabel('Depletion, cfs')
# Out:
# Text(0, 0.5, 'Depletion, cfs')

# %%
LPR_baseline_flow = 8.6

# %%
all_time_series= LPR_baseline_flow-all_time_series
cum_depl = LPR_baseline_flow - cum_depl

# %%
fig,ax = plt.subplots(nrows=1, ncols=1)
ax.plot(cum_depl, c='r')
ax.set_title('Streamflow, LPR at Hoover,Base Case Analysis')
ax.set_xlabel("Days")
ax.set_ylabel('Streamflow, cfs')
# Out:
# Text(0, 0.5, 'Streamflow, cfs')

# %% [markdown]
# ### now what about the metrics?

# %%
all_metrics = pycap_metrics(depl, well_dict,combdict, base_run_path, pycap_run_name)
# Out:
# Writing report to ../pycap_runs/student_run/tmprun.yml.import_report
#
#
#
# Successfully parsed ../pycap_runs/student_run/tmprun.yml (high five!)
# *************************
# Summary follows:
#
# WELLS:
# 326 existing wells:
# 	466
# 	467
# 	490
# 	509
# 	602
# 	603
# 	798
# 	807
# 	850
# 	862
# 	1013
# 	1302
# 	1323
# 	1486
# 	1584
# 	1589
# 	1643
# 	1683
# 	1860
# 	2544
# 	2750
# 	2886
# 	3473
# 	3949
# 	4171
# 	23610
# 	23611
# 	23618
# 	23620
# 	23627
# 	23629
# 	23630
# 	23631
# 	23635
# 	23637
# 	23638
# 	23639
# 	23645
# 	23646
# 	23648
# 	23653
# 	23695
# 	23697
# 	23698
# 	23699
# 	23700
# 	23709
# 	23710
# 	23715
# 	23716
# 	23720
# 	23721
# 	23722
# 	23723
# 	23726
# 	23727
# 	23728
# 	23729
# 	23751
# 	23752
# 	23753
# 	23754
# 	23755
# 	23756
# 	23757
# 	23758
# 	23770
# 	23776
# 	23778
# 	23781
# 	23790
# 	23791
# 	23794
# 	23795
# 	23798
# 	23800
# 	23807
# 	23816
# 	23818
# 	23820
# 	23823
# 	23836
# 	23837
# 	23846
# 	23847
# 	23848
# 	23851
# 	23864
# 	23865
# 	23866
# 	23867
# 	23868
# 	23869
# 	23870
# 	23876
# 	23881
# 	23883
# 	23886
# 	23888
# 	23889
# 	23890
# 	23895
# 	23898
# 	23908
# 	23909
# 	23910
# 	23913
# 	23915
# 	23919
# 	23926
# 	23928
# 	23929
# 	23930
# 	23934
# 	23936
# 	23937
# 	23939
# 	23942
# 	23944
# 	23948
# 	LPR:23630
# 	LPR:23631
# 	LPR:23635
# 	LPR:23637
# 	LPR:23638
# 	LPR:23639
# 	LPR:23645
# 	LPR:23646
# 	LPR:23648
# 	LPR:23653
# 	LPR:23695
# 	LPR:23697
# 	LPR:23698
# 	LPR:23699
# 	LPR:23700
# 	LPR:23709
# 	LPR:23710
# 	LPR:23715
# 	LPR:23716
# 	LPR:23720
# 	LPR:23721
# 	LPR:23722
# 	LPR:23723
# 	LPR:23726
# 	LPR:23727
# 	LPR:23728
# 	LPR:23729
# 	LPR:23751
# 	LPR:23752
# 	LPR:23753
# 	LPR:23754
# 	LPR:23755
# 	LPR:23756
# 	LPR:23757
# 	LPR:23758
# 	LPR:23770
# 	LPR:23776
# 	LPR:23778
# 	LPR:23781
# 	LPR:23790
# 	LPR:23791
# 	LPR:23794
# 	LPR:23795
# 	LPR:23798
# 	LPR:23800
# 	LPR:23807
# 	LPR:23816
# 	LPR:23818
# 	LPR:23820
# 	LPR:23823
# 	LPR:23836
# 	LPR:23837
# 	LPR:23846
# 	LPR:23847
# 	LPR:23848
# 	LPR:23851
# 	LPR:23864
# 	LPR:23865
# 	LPR:23866
# 	LPR:23867
# 	LPR:23868
# 	LPR:23869
# 	LPR:23870
# 	LPR:23876
# 	LPR:23881
# 	LPR:23883
# 	LPR:23886
# 	LPR:23888
# 	LPR:23889
# 	LPR:23890
# 	LPR:23895
# 	LPR:23898
# 	LPR:23908
# 	LPR:23909
# 	LPR:23910
# 	LPR:23913
# 	LPR:23915
# 	LPR:23919
# 	LPR:23926
# 	LPR:23928
# 	LPR:23929
# 	LPR:23930
# 	LPR:23934
# 	LPR:23936
# 	LPR:23937
# 	LPR:23939
# 	LPR:23942
# 	LPR:23944
# 	LPR:23948
# 	LPR:23956
# 	LPR:23961
# 	LPR:23962
# 	LPR:23963
# 	LPR:23966
# 	LPR:23967
# 	LPR:23972
# 	LPR:23977
# 	LPR:23978
# 	LPR:23979
# 	LPR:23980
# 	LPR:23981
# 	LPR:23983
# 	LPR:23984
# 	LPR:23985
# 	LPR:23987
# 	LPR:23998
# 	LPR:24003
# 	LPR:24005
# 	LPR:24010
# 	LPR:24011
# 	LPR:24012
# 	LPR:24016
# 	LPR:24024
# 	LPR:24030
# 	LPR:24033
# 	LPR:24036
# 	LPR:24037
# 	LPR:24042
# 	LPR:24043
# 	LPR:24045
# 	LPR:24047
# 	LPR:24049
# 	LPR:24059
# 	LPR:24063
# 	LPR:24066
# 	LPR:24080
# 	LPR:24091
# 	LPR:24093
# 	LPR:24110
# 	LPR:24120
# 	LPR:24121
# 	LPR:24125
# 	LPR:24130
# 	LPR:24135
# 	LPR:24137
# 	LPR:24165
# 	LPR:24166
# 	LPR:24169
# 	LPR:24172
# 	LPR:24195
# 	LPR:24197
# 	LPR:24203
# 	LPR:24216
# 	LPR:24225
# 	LPR:24226
# 	LPR:24227
# 	LPR:24239
# 	LPR:24240
# 	LPR:24247
# 	LPR:24249
# 	LPR:24252
# 	LPR:24253
# 	LPR:24256
# 	LPR:24265
# 	LPR:24266
# 	LPR:24274
# 	LPR:24279
# 	LPR:24283
# 	LPR:24285
# 	LPR:24286
# 	LPR:24291
# 	LPR:24293
# 	LPR:24294
# 	LPR:24302
# 	LPR:24305
# 	LPR:24307
# 	LPR:24311
# 	LPR:24317
# 	LPR:24323
# 	LPR:58403
# 	LPR:58405
# 	LPR:58406
# 	LPR:58407
# 	LPR:58410
# 	LPR:58411
# 	LPR:58414
# 	LPR:58416
# 	LPR:58424
# 	LPR:58433
# 	LPR:58434
# 	LPR:67673
# 	LPR:67895
# 	LPR:68008
# 	LPR:68216
# 	LPR:68218
# 	LPR:68219
# 	LPR:68220
# 	LPR:68221
# 	LPR:68294
# 	LPR:68475
# 	LPR:68529
# 	LPR:68693
# 	LPR:68695
# 	LPR:68872
# 	LPR:68917
# 	LPR:68925
# 	LPR:68926
# 	LPR:69049
# 	LPR:69065
# 	LPR:69282
# 	LPR:69288
# 	LPR:69289
# 	LPR:69480
# 	LPR:69508
# 	LPR:69576
# 	LPR:69635
# 	LPR:69636
# 	LPR:69638
# 	LPR:69669
# 	LPR:69970
# 	LPR:69990
# 	LPR:70119
# 	LPR:70120
# 	LPR:70186
# 	LPR:70191
# 	LPR:70263
# 	LPR:70517
# 	LPR:70519
# 	LPR:70520
# 	LPR:70548
# 	LPR:70881
# 	LPR:70961
# 	LPR:70974
# 	LPR:70975
# 	LPR:71044
# 	LPR:71062
# 	LPR:71063
# 	LPR:71109
# 	LPR:71110
# 	LPR:71117
# 	LPR:71156
# 	LPR:71199
# 	LPR:71495
# 	LPR:71935
# 	LPR:71998
# 	LPR:72082
# 	LPR:72094
# 	LPR:72095
# 	LPR:72269
# 	LPR:72301
# 	LPR:72304
# 	LPR:72421
# 	LPR:72422
# 	LPR:72436
# 	LPR:72437
# 	LPR:72607
# 	LPR:72610
# 	LPR:72713
# 	LPR:72756
# 	LPR:72983
# 	LPR:73153
# 	LPR:73262
# 	LPR:73280
# 	LPR:73281
# 	LPR:73372
# 	LPR:73440
# 	LPR:73481
# 	LPR:73715
# 	LPR:73737
# 	LPR:73761
# 	LPR:73762
# 	LPR:73906
# 	LPR:73940
# 	LPR:73942
# 	LPR:74131
# 	LPR:74280
# 	LPR:84404
# 	LPR:84409
# 	LPR:84411
# 	LPR:91103
# 	LPR:91173
# 	LPR:91808
# 	LPR:91996
# 	LPR:91997
# 	LPR:92099
# 	LPR:92184
# 	LPR:92299
# 	LPR:92696
# 	LPR:92714
# 	LPR:92724
# 	LPR:92743
# 	LPR:92808
# 	LPR:92885
# 	LPR:92981
# 	LPR:93142
# 	LPR:93143
# 	LPR:93349
# 	LPR:93422
# 	LPR:93423
# 	LPR:93424
# 	LPR:93469
# 	LPR:93832
# 	LPR:94302
# 	LPR:94988
# 	LPR:95068
# DRAWDOWN RESPONSES:
# 	LakeEmily

# %% [markdown]
# # FINALLY, let's see what we got!

# %%
all_metrics
# Out:
#                   wells_total_q  wells_total_q_ag       receipts  \
# LPR_Single_Run90      13.049797          2.108579  714146.286712
#
#                   total_depletion  truncated_depletion  fish_prob
# LPR_Single_Run90         0.530518             0.078477   0.723933

# %%
all_metrics.to_csv(base_run_path / f"{pycap_run_name}_results.csv")
