# %%
import sys
sys.path.insert(0,'../scripts')
from pycap_for_PESTPP_MOU import prepare_MOU_files
from pathlib import Path
import zipfile
import pyemu

# %% [markdown]
# # First prepare the MOU files
# In the `../scripts` directory the script called `pycap_for_PESTPP_MOU.py` has all the logic required to configure a directory in which to run PEST++ MOU for a given configuration. In the next cell, 5 variables must be specified. They are outlined here:
#  -  `pump_lbound_fraction` is a lower bound on pumping, applied to each well used in the optimization. This takes the form of a fraction (typically between 0.0 and 1.0) to be multiplied by the baseline pumping rate to form a lower bound. *
#  -  `pump_ubound_fraction` is an upper bound on pumping, applied to each well used in the optimization. This takes the form of a fraction (typically around 1.0, but can be selected) to be multiplied by the baseline pumping rate to form a lower bound.
#  - `objectives` determined what the multiple objectives to be optimized for are. You can make more custom versions of this, but currently three options are supported:
#     - `depletion_q` aims to _minimize_ depletion (in CFS) and _maximize_ agricultural pumping (in CFS)
#     - `fish_q` aims to _maximize_ the probability of Brook trout presence (in %) and _maximize_ agricultural pumping (in CFS)
#     - `fish_dollars` aims to _maximize_ the probability of Brook trout presence (in %) and _maximize_ agricultural receipts (in cashmoney $$$)
# - `depletion_potential_threshold` is a threshold (in the range of 0.0 to 1.0) of depletion potential below which wells are not managed for optimization. In other words, if a well's depletion potential falls below the threshold, it is maintained at its original baseline pumping rate throughout the optimization process. A spatial analysis can help guide this decision - see notebook `01_Calculate_Depletion_Potential.ipynb` for guidance.
# - `scenario_name` will be assigned to both the configuration file saving these choices (and used by `06_MOU_postprocess.ipynb` for visualization and further analysis) and used to name the folder in which it will run.
#     - the file goes in a subdirectory within this notebooks directory (`notebooks/configurations`) and is named `<scenario_name>.yml`
#
#
# \* note that for the `fish_dollars` objectives set, there is a pumping threshold hard-coded that sets any pumping less than 70% of the baseline to 0.

# %%
run_name, run_path = prepare_MOU_files(pump_lbound_fraction=0.0,
                      pump_ubound_fraction=1.0,
                      objectives='fish_dollars',            #'depletion_q', 'fish_q', or 'fish_dollars'
                      depletion_potential_threshold=0.2,
                      scenario_name='fish_dollars_Tplus10per_0.0_1.0_0.2')
# Out:
# wrote configuration to: configurations/fish_dollars_Tplus10per_0.0_1.0_0.2.yml
# noptmax:50, npar_adj:13, nnz_obs:2
# ALL READY TO RUN:
#  scenario: fish_dollars_Tplus10per_0.0_1.0_0.2
#  directory: ../pycap_runs/pycap_pest/run_fish_dollars_Tplus10per_0.0_1.0_0.2

# %% [markdown]
# ___
# ### Now run PESTPP-MOU below - note, this might take 20 or 30 minutes or up to a couple hours depending on your computer*. Go have a ☕️ or a 🍺 and think about life choices (and note that if we were running with MODFLOW instead of pycap, this would take overnight on a few hundred computers in parallel #winning )
#
# ##### *Accept this as one of the benefits of modeling. One day you will tell your boss 'yeah, i'm running a model right now' as you walk out the door to go for a bike ride"

# %%
pyemu.os_utils.run(f"pestpp-mou {run_name}.pst /e",cwd=str(run_path))
# Out:
# ./pestpp-mou fish_dollars_Tplus10per_0.0_1.0_0.2.pst /e
#
#
#              pestpp-mou: multi-objective optimization under uncertainty
#
#                    by the PEST++ development team
#
# ...processing command line: ' ./pestpp-mou fish_dollars_Tplus10per_0.0_1.0_0.2.pst /e'
# ...using external run manager
#
#
# version: 5.2.24
# binary compiled on Nov 12 2025 at 19:12:47
# using control file: "fish_dollars_Tplus10per_0.0_1.0_0.2.pst"
# in directory: "/workspaces/LPR_redux/LPR_pycap_opt/pycap_runs/pycap_pest/run_fish_dollars_Tplus10per_0.0_1.0_0.2"
# on host: "codespaces-4360a8"
# on a(n) linux operating system
# with release configuration
# started at 04/13/26 03:29:09
#
# processing control file fish_dollars_Tplus10per_0.0_1.0_0.2.pst
# parameter warning: 327 parameters are at upper bound
#               starting external run manager ...
#
#
#   ---  initializing MOEA process  ---
# ...using 'nsga2' env selector
# ...using binary tournament mating pool selector
# ...saving generation specific populations and archives every nth generation 1
# using all adjustable parameters as decision variables:  13
# ...number of decision variables:  13
# ...max run fail:  3
# ...'opt_chance_points' = SINGLE, evaluating chance at representative point
# ...using the following observations as objectives:
#                    AG_RECEIPTS   maximize
#                      FISH_PROB   maximize
# ...2 obs-based constraints/objectives, see rec file for listing
# ...not using chance constraints
# ...using particle swarm generator
# ...loading dv population from csv file initial_dvpop.csv
# ...dv population with 26 members read from 'initial_dvpop.csv'
#
# checking for denormal values in dv population
# ... saved initial dv population to  fish_dollars_Tplus10per_0.0_1.0_0.2.0.dv_pop.csv
# ...running initial population of size 26
# ...running population of size  26
# 04/13/26 03:29:09 external run manager calling forward run command(s)
# 04/13/26 03:29:09 calling forward run command: 'python run_pycap_standalone_opt_mou_fish_dollars.py fish_dollars_Tplus10per_0.0_1.0_0.2'
# ...pid: 101635
# ...exit_code: 101635
# ...status: 0
# 04/13/26 03:30:08 forward run command(s) finished, took 58.29 seconds
# ... saved observation population to  fish_dollars_Tplus10per_0.0_1.0_0.2.0.obs_pop.csv
#
#   ---  initial population decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# WELL_23627__Q            276.5          0      276.275      26.9395      231.991      322.572
# WELL_23645__Q            158.8          0      161.951      19.3042      129.232      189.975
# WELL_23653__Q            263.6          0       253.23       33.635      211.704      315.538
# WELL_23755__Q            794.6          0      808.215      99.6478      652.471      953.176
# WELL_23770__Q            239.9          0      239.207      27.6366      193.804      287.714
# WELL_23816__Q            149.4          0      155.426      15.6467      130.119      178.778
# WELL_23876__Q            197.6          0      193.881      19.8087       161.72      231.985
# WELL_23934__Q            370.6          0      365.085       42.829      297.507      441.513
# WELL_24239__Q            271.5          0      271.473      30.4459      222.711      323.679
# WELL_24323__Q            206.4          0      208.513      23.7606      165.317      245.366
# WELL_68529__Q            219.9          0       219.21      25.7571      177.216      261.327
# WELL_69049__Q             37.6          0      35.9116      4.37553       30.268      44.6306
# WELL_69970__Q             62.9          0      64.6633      6.29825      50.4809      74.2588
#
#
#   ---  initial population objective function summary:  ---
# using member 2 as nearest-to-mean single point
#     with distance of 78.1408 from mean of decision variable population
# objective function   direction         mean      std dev          min          max         knee
#
# AG_RECEIPTS           maximize 1.235633e+07     21894.48 1.230815e+07 1.239913e+07 1.234925e+07
# FISH_PROB             maximize    0.5216735   0.01074101    0.5067523    0.5478944     0.521447
#
# ... saved initial dv population to  fish_dollars_Tplus10per_0.0_1.0_0.2.0.dv_pop.csv
# ...performing initial pareto dominance sort
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.summary.csv
# initialized archives with 10 nondominated members
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.archive.summary.csv
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.trimmed.archive.summary.csv
# ...saved decision variable population of size 10 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 10 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.0.archive.dv_pop.csv'
# ...saved observation population of size 10 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 10 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.0.archive.obs_pop.csv'
# ...number of initial feasible solutions: 10
#
#   ---  initialization complete  ---
#
#   ---  starting generation  1  ---
# ...generating PSO population of size 26
# ...running population of size  26
# 04/13/26 03:30:08 external run manager calling forward run command(s)
# 04/13/26 03:30:08 calling forward run command: 'python run_pycap_standalone_opt_mou_fish_dollars.py fish_dollars_Tplus10per_0.0_1.0_0.2'
# ...pid: 101959
# ...exit_code: 101959
# ...status: 0
# 04/13/26 03:30:54 forward run command(s) finished, took 45.991 seconds
# ...saved decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.dv_pop.csv'
# ...saved generation-specific decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.1.dv_pop.csv'
# ...saved observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.obs_pop.csv'
# ...saved generation-specific observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.1.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  52
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.summary.csv
# updating archive
# adding 11 non-dominated members to archive
# pareto dominance sorting archive of size 21
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.archive.summary.csv
# resizing archive from 21 to 21 current non-dominated solutions
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.trimmed.archive.summary.csv
# ...saved decision variable population of size 21 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 21 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.1.archive.dv_pop.csv'
# ...saved observation population of size 21 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 21 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.1.archive.obs_pop.csv'
# ...resizing current populations to  26
#
#   ---  generation 1 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# WELL_23627__Q            276.5          0      234.048      53.7998      114.154      317.113
# WELL_23645__Q            158.8          0      162.452      15.0492      138.961      189.975
# WELL_23653__Q            263.6          0      219.561      43.5285      118.087       308.05
# WELL_23755__Q            794.6          0      659.257      114.182      337.905      921.734
# WELL_23770__Q            239.9          0      232.256      25.3736      140.031      283.112
# WELL_23816__Q            149.4          0      147.252      16.7108      109.489      174.216
# WELL_23876__Q            197.6          0      176.501      29.4945      113.855      218.661
# WELL_23934__Q            370.6          0      361.979      34.1532      302.342      441.513
# WELL_24239__Q            271.5          0      260.886      37.0352      130.406      323.679
# WELL_24323__Q            206.4          0      200.209      31.6027      82.6737      241.201
# WELL_68529__Q            219.9          0      214.683      24.3898      158.661      260.909
# WELL_69049__Q             37.6          0      35.1398      3.94422      28.9393      43.0012
# WELL_69970__Q             62.9          0      61.7379      6.87609      41.8403      74.2588
#
#
#   ---  generation 1 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# WELL_23627__Q           42.2264     15.2842     5.45812     1.69207     117.837     50.7936
# WELL_23645__Q         -0.500849   -0.309259           0           0     -9.7292    -7.52849
# WELL_23653__Q           33.6694      13.296     7.48852     2.37325     93.6178      44.221
# WELL_23755__Q           148.958     18.4305     31.4427     3.29873     314.566     48.2115
# WELL_23770__Q            6.9513     2.90598     4.60178     1.59943     53.7729      27.746
# WELL_23816__Q           8.17447      5.2594     4.56138     2.55143     20.6299     15.8546
# WELL_23876__Q           17.3806     8.96453     13.3247     5.74378     47.8657     29.5978
# WELL_23934__Q           3.10622    0.850823           0           0    -4.83568     -1.6254
# WELL_24239__Q           10.5872      3.8999           0           0     92.3054     41.4462
# WELL_24323__Q            8.3044     3.98268     4.16464     1.69732     82.6433     49.9908
# WELL_68529__Q           4.52672     2.06502    0.418325    0.160077     18.5549     10.4702
# WELL_69049__Q          0.771831     2.14925     1.62943     3.65091     1.32865     4.38962
# WELL_69970__Q           2.92537       4.524           0           0      8.6406     17.1166
#
#
#   ---  generation 1 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member 6 as single, 'optimal' point
#    with distance of 0.109013 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# AG_RECEIPTS           maximize  1.22777e+07     76648.15 1.212349e+07 1.239913e+07 1.239913e+07
# FISH_PROB             maximize    0.5573711    0.0307252    0.5067523    0.6175038    0.5084904
#
#
#   ---  generation 1 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# AG_RECEIPTS              78626.7    0.636327           0           0      184663     1.50033    -49874.1   -0.403863
# FISH_PROB             -0.0356976    -6.84289  -0.0696094    -12.7049           0           0   0.0129566     2.48474
#
# ...number of feasible solutions at the end of generation 1: 21
#
#   ---  starting generation  2  ---
# ...generating PSO population of size 26
# ...running population of size  26
# 04/13/26 03:30:54 external run manager calling forward run command(s)
# 04/13/26 03:30:54 calling forward run command: 'python run_pycap_standalone_opt_mou_fish_dollars.py fish_dollars_Tplus10per_0.0_1.0_0.2'
# ...pid: 102207
# ...exit_code: 102207
# ...status: 0
# 04/13/26 03:31:39 forward run command(s) finished, took 45.1 seconds
# ...saved decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.dv_pop.csv'
# ...saved generation-specific decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.2.dv_pop.csv'
# ...saved observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.obs_pop.csv'
# ...saved generation-specific observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.2.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  52
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.summary.csv
# updating archive
# adding 8 non-dominated members to archive
# pareto dominance sorting archive of size 29
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.archive.summary.csv
# resizing archive from 29 to 21 current non-dominated solutions
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.trimmed.archive.summary.csv
# ...saved decision variable population of size 21 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 21 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.2.archive.dv_pop.csv'
# ...saved observation population of size 21 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 21 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.2.archive.obs_pop.csv'
# ...resizing current populations to  26
#
#   ---  generation 2 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# WELL_23627__Q            276.5          0       233.62      59.9998      73.5466      317.113
# WELL_23645__Q            158.8          0      163.304       14.353      141.673      189.975
# WELL_23653__Q            263.6          0       219.19       36.419      148.286       308.05
# WELL_23755__Q            794.6          0      625.224      146.455      274.792      921.734
# WELL_23770__Q            239.9          0      235.865      23.7091      140.031      283.112
# WELL_23816__Q            149.4          0      147.592      15.5147      111.796      174.216
# WELL_23876__Q            197.6          0      184.653      23.0204      117.902      218.661
# WELL_23934__Q            370.6          0      352.191      44.8226      234.809      441.513
# WELL_24239__Q            271.5          0      260.824      36.1151      143.679      323.679
# WELL_24323__Q            206.4          0      198.888      37.0722      46.2325      241.201
# WELL_68529__Q            219.9          0      212.863      30.2055      128.263      260.909
# WELL_69049__Q             37.6          0      35.6022      3.50667      29.6239      43.0012
# WELL_69970__Q             62.9          0      62.8689      5.49667      47.1112      74.2588
#
#
#   ---  generation 2 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# WELL_23627__Q          0.428762    0.183194           0           0     40.6078     35.5727
# WELL_23645__Q         -0.852404   -0.524712           0           0    -2.71183    -1.95151
# WELL_23653__Q          0.370202    0.168611           0           0    -30.1993    -25.5738
# WELL_23755__Q           34.0321      5.1622           0           0     63.1131     18.6778
# WELL_23770__Q          -3.60962    -1.55416           0           0           0           0
# WELL_23816__Q         -0.340227   -0.231052           0           0    -2.30644    -2.10654
# WELL_23876__Q          -8.15168    -4.61849           0           0    -4.04736    -3.55484
# WELL_23934__Q           9.78731     2.70384           0           0     67.5334     22.3367
# WELL_24239__Q          0.061726   0.0236602           0           0    -13.2729    -10.1781
# WELL_24323__Q           1.32086     0.65974           0           0     36.4413     44.0784
# WELL_68529__Q           1.82025    0.847879           0           0     30.3982     19.1592
# WELL_69049__Q         -0.462405     -1.3159           0           0    -0.68452    -2.36536
# WELL_69970__Q          -1.13105    -1.83201           0           0    -5.27086    -12.5976
#
#
#   ---  generation 2 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member 6 as single, 'optimal' point
#    with distance of 0.134244 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# AG_RECEIPTS           maximize 1.227046e+07     90532.81 1.206784e+07 1.239913e+07 1.239913e+07
# FISH_PROB             maximize    0.5628308   0.03865086    0.5067523    0.6427348    0.5084904
#
#
#   ---  generation 2 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# AG_RECEIPTS              7242.15   0.0589862           0           0     55641.6    0.458958           0           0
# FISH_PROB             -0.0054597   -0.979545   -0.025231    -4.08596           0           0           0           0
#
# ...number of feasible solutions at the end of generation 2: 21
#
#   ---  starting generation  3  ---
# ...generating PSO population of size 26
# ...running population of size  26
# 04/13/26 03:31:39 external run manager calling forward run command(s)
# 04/13/26 03:31:39 calling forward run command: 'python run_pycap_standalone_opt_mou_fish_dollars.py fish_dollars_Tplus10per_0.0_1.0_0.2'
# ...pid: 102479
# ...exit_code: 102479
# ...status: 0
# 04/13/26 03:32:24 forward run command(s) finished, took 45.531 seconds
# ...saved decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.dv_pop.csv'
# ...saved generation-specific decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.3.dv_pop.csv'
# ...saved observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.obs_pop.csv'
# ...saved generation-specific observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.3.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  52
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.summary.csv
# updating archive
# adding 11 non-dominated members to archive
# pareto dominance sorting archive of size 32
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.archive.summary.csv
# resizing archive from 32 to 26 current non-dominated solutions
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.trimmed.archive.summary.csv
# ...saved decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.3.archive.dv_pop.csv'
# ...saved observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.3.archive.obs_pop.csv'
# ...resizing current populations to  26
#
#   ---  generation 3 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# WELL_23627__Q            276.5          0      207.626      74.6759      48.2666      306.134
# WELL_23645__Q            158.8          0      163.741       14.067      140.085      189.975
# WELL_23653__Q            263.6          0      213.964      38.8484      121.429       308.05
# WELL_23755__Q            794.6          0       562.44      167.336      158.761      851.903
# WELL_23770__Q            239.9          0      242.081      11.5429      208.013      283.112
# WELL_23816__Q            149.4          0      150.232      11.5234      111.796      171.646
# WELL_23876__Q            197.6          0      185.699      22.8292      117.902      218.661
# WELL_23934__Q            370.6          0       352.34      39.9948      276.445      441.513
# WELL_24239__Q            271.5          0      262.748      30.0155      205.035      323.679
# WELL_24323__Q            206.4          0      199.161      22.8733      159.835      241.201
# WELL_68529__Q            219.9          0      194.692      50.5042      64.1166      260.909
# WELL_69049__Q             37.6          0      36.2478      3.16282      30.3703      43.0012
# WELL_69970__Q             62.9          0      63.3618      4.12069      56.2388      74.2588
#
#
#   ---  generation 3 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# WELL_23627__Q           25.9938     11.1266     10.9791     3.46219       25.28     34.3728
# WELL_23645__Q         -0.436707   -0.267419           0           0     1.58763     1.12063
# WELL_23653__Q           5.22647     2.38444           0           0     26.8565     18.1113
# WELL_23755__Q           62.7842     10.0419     69.8304     7.57599      116.03     42.2249
# WELL_23770__Q          -6.21535    -2.63513           0           0    -67.9824    -48.5481
# WELL_23816__Q          -2.64001    -1.78872     2.56985     1.47509           0           0
# WELL_23876__Q          -1.04667   -0.566834           0           0           0           0
# WELL_23934__Q         -0.148217  -0.0420843           0           0    -41.6363     -17.732
# WELL_24239__Q          -1.92375   -0.737568           0           0    -61.3568    -42.7042
# WELL_24323__Q         -0.272986   -0.137257           0           0    -113.602     -245.72
# WELL_68529__Q            18.171     8.53648           0           0     64.1461     50.0115
# WELL_69049__Q         -0.645592    -1.81335           0           0   -0.746434    -2.51971
# WELL_69970__Q         -0.492893   -0.784001           0           0    -9.12768    -19.3748
#
#
#   ---  generation 3 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member 6 as single, 'optimal' point
#    with distance of 0.136481 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# AG_RECEIPTS           maximize 1.224971e+07     100115.1 1.205228e+07 1.239913e+07 1.239913e+07
# FISH_PROB             maximize    0.5740265   0.04257417    0.5084904    0.6449718    0.5084904
#
#
#   ---  generation 3 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# AG_RECEIPTS              20748.7    0.169095           0           0     15568.3    0.129006           0           0
# FISH_PROB             -0.0111957    -1.98917 -0.00223703   -0.348048 -0.00173811   -0.342991           0           0
#
# ...number of feasible solutions at the end of generation 3: 26
#
#   ---  starting generation  4  ---
# ...generating PSO population of size 26
# ...running population of size  26
# 04/13/26 03:32:25 external run manager calling forward run command(s)
# 04/13/26 03:32:25 calling forward run command: 'python run_pycap_standalone_opt_mou_fish_dollars.py fish_dollars_Tplus10per_0.0_1.0_0.2'
# ...pid: 102734
# ...exit_code: 102734
# ...status: 0
# 04/13/26 03:33:11 forward run command(s) finished, took 46.555 seconds
# ...saved decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.dv_pop.csv'
# ...saved generation-specific decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.4.dv_pop.csv'
# ...saved observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.obs_pop.csv'
# ...saved generation-specific observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.4.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  52
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.summary.csv
# updating archive
# adding 7 non-dominated members to archive
# pareto dominance sorting archive of size 33
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.archive.summary.csv
# resizing archive from 33 to 32 current non-dominated solutions
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.trimmed.archive.summary.csv
# ...saved decision variable population of size 32 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 32 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.4.archive.dv_pop.csv'
# ...saved observation population of size 32 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 32 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.4.archive.obs_pop.csv'
# ...resizing current populations to  26
#
#   ---  generation 4 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# WELL_23627__Q            276.5          0      182.137      73.0467      30.3921      282.735
# WELL_23645__Q            158.8          0      157.965      18.1414      111.587      189.975
# WELL_23653__Q            263.6          0       210.29      43.7413      121.429       308.05
# WELL_23755__Q            794.6          0      440.478      226.754            0      851.903
# WELL_23770__Q            239.9          0      240.423      14.0284      187.587      283.112
# WELL_23816__Q            149.4          0      150.241      10.3098      111.796      171.646
# WELL_23876__Q            197.6          0      185.648      20.4111      129.009      218.661
# WELL_23934__Q            370.6          0      348.216      43.5242      234.327      441.513
# WELL_24239__Q            271.5          0      248.387      30.1887       198.53      305.552
# WELL_24323__Q            206.4          0       197.44      23.6708       136.49      241.201
# WELL_68529__Q            219.9          0      187.002      54.8903      40.3877      243.255
# WELL_69049__Q             37.6          0      36.3463      2.62131       30.512      43.0012
# WELL_69970__Q             62.9          0      63.5787      2.78164      60.9186      74.2588
#
#
#   ---  generation 4 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# WELL_23627__Q           25.4885     12.2762     23.3993     7.64346     17.8745     37.0329
# WELL_23645__Q           5.77623     3.52766           0           0     28.4984     20.3437
# WELL_23653__Q           3.67371     1.71698           0           0           0           0
# WELL_23755__Q           121.962     21.6845           0           0     158.761         100
# WELL_23770__Q           1.65763    0.684743           0           0     20.4267     9.81988
# WELL_23816__Q       -0.00897707 -0.00597548           0           0           0           0
# WELL_23876__Q         0.0509412   0.0274321           0           0    -11.1065    -9.42012
# WELL_23934__Q           4.12407     1.17048           0           0     42.1179     15.2355
# WELL_24239__Q           14.3606     5.46556     18.1261     5.60003     6.50571     3.17297
# WELL_24323__Q           1.72116    0.864205           0           0     23.3445     14.6054
# WELL_68529__Q           7.68948     3.94957     17.6541     6.76639      23.729      37.009
# WELL_69049__Q        -0.0984962    -0.27173           0           0   -0.141746   -0.466727
# WELL_69970__Q         -0.216835   -0.342217           0           0    -4.67973    -8.32117
#
#
#   ---  generation 4 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member 6 as single, 'optimal' point
#    with distance of 0.15168 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# AG_RECEIPTS           maximize 1.221245e+07     107707.7 1.201806e+07 1.239913e+07 1.239913e+07
# FISH_PROB             maximize    0.5899271   0.04261504    0.5084904    0.6601708    0.5084904
#
#
#   ---  generation 4 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# AG_RECEIPTS              37257.1    0.304147           0           0     34214.4    0.283884           0           0
# FISH_PROB             -0.0159006    -2.77002   -0.015199    -2.35653           0           0           0           0
#
# ...number of feasible solutions at the end of generation 4: 32
#
#   ---  starting generation  5  ---
# ...generating PSO population of size 26
# ...running population of size  26
# 04/13/26 03:33:11 external run manager calling forward run command(s)
# 04/13/26 03:33:11 calling forward run command: 'python run_pycap_standalone_opt_mou_fish_dollars.py fish_dollars_Tplus10per_0.0_1.0_0.2'
# ...pid: 102986
# ...exit_code: 102986
# ...status: 0
# 04/13/26 03:33:56 forward run command(s) finished, took 44.786 seconds
# ...saved decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.dv_pop.csv'
# ...saved generation-specific decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.5.dv_pop.csv'
# ...saved observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.obs_pop.csv'
# ...saved generation-specific observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.5.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  52
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.summary.csv
# updating archive
# adding 9 non-dominated members to archive
# pareto dominance sorting archive of size 41
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.archive.summary.csv
# resizing archive from 41 to 33 current non-dominated solutions
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.trimmed.archive.summary.csv
# ...saved decision variable population of size 33 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 33 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.5.archive.dv_pop.csv'
# ...saved observation population of size 33 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 33 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.5.archive.obs_pop.csv'
# ...resizing current populations to  26
#
#   ---  generation 5 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# WELL_23627__Q            276.5          0      183.904      77.8517      18.2542      282.735
# WELL_23645__Q            158.8          0      157.552      18.2283      111.587      189.975
# WELL_23653__Q            263.6          0       203.74      45.4077      110.379       308.05
# WELL_23755__Q            794.6          0      427.134      230.597            0      851.903
# WELL_23770__Q            239.9          0      242.569       9.1773      236.005      283.112
# WELL_23816__Q            149.4          0      150.986       8.6353      123.464      171.646
# WELL_23876__Q            197.6          0      183.746      21.8125      129.009      218.661
# WELL_23934__Q            370.6          0       338.75      54.9619      208.594      441.513
# WELL_24239__Q            271.5          0      250.191      30.6205       198.53      305.552
# WELL_24323__Q            206.4          0       202.03       18.571      159.835      241.201
# WELL_68529__Q            219.9          0      192.507      48.5354      40.3877      243.255
# WELL_69049__Q             37.6          0      36.3488      2.88557      28.3396      43.0012
# WELL_69970__Q             62.9          0      63.4607      3.04811      56.3636      74.2588
#
#
#   ---  generation 5 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# WELL_23627__Q          -1.76647   -0.969854           0           0     12.1379     39.9378
# WELL_23645__Q          0.413308    0.261645           0           0           0           0
# WELL_23653__Q           6.54999     3.11474           0           0     11.0504     9.10028
# WELL_23755__Q           13.3439      3.0294           0           0           0           0
# WELL_23770__Q          -2.14595   -0.892571           0           0    -48.4181     -25.811
# WELL_23816__Q          -0.74481   -0.495744           0           0    -11.6679    -10.4368
# WELL_23876__Q           1.90229     1.02468           0           0           0           0
# WELL_23934__Q           9.46513     2.71818           0           0     25.7332     10.9817
# WELL_24239__Q          -1.80411   -0.726331           0           0           0           0
# WELL_24323__Q          -4.59027     -2.3249           0           0    -23.3445    -17.1034
# WELL_68529__Q          -5.50485    -2.94373           0           0           0           0
# WELL_69049__Q       -0.00251094 -0.00690837           0           0     2.17247     7.12003
# WELL_69970__Q          0.118003    0.185602           0           0     4.55493     7.47707
#
#
#   ---  generation 5 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member 6 as single, 'optimal' point
#    with distance of 0.15226 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# AG_RECEIPTS           maximize 1.220904e+07       111682 1.200401e+07 1.239913e+07 1.239913e+07
# FISH_PROB             maximize    0.5922642   0.04374502    0.5084904    0.6607508    0.5084904
#
#
#   ---  generation 5 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# AG_RECEIPTS              3415.07   0.0279639           0           0       14052    0.116924           0           0
# FISH_PROB            -0.00233709   -0.396166-0.000579971  -0.0878517           0           0           0           0
#
# ...number of feasible solutions at the end of generation 5: 33
#
#   ---  starting generation  6  ---
# ...generating PSO population of size 26
# ...running population of size  26
# 04/13/26 03:33:56 external run manager calling forward run command(s)
# 04/13/26 03:33:56 calling forward run command: 'python run_pycap_standalone_opt_mou_fish_dollars.py fish_dollars_Tplus10per_0.0_1.0_0.2'
# ...pid: 103247
# ...exit_code: 103247
# ...status: 0
# 04/13/26 03:34:41 forward run command(s) finished, took 44.543 seconds
# ...saved decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.dv_pop.csv'
# ...saved generation-specific decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.6.dv_pop.csv'
# ...saved observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.obs_pop.csv'
# ...saved generation-specific observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.6.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  52
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.summary.csv
# updating archive
# adding 8 non-dominated members to archive
# pareto dominance sorting archive of size 41
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.archive.summary.csv
# resizing archive from 41 to 36 current non-dominated solutions
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.trimmed.archive.summary.csv
# ...saved decision variable population of size 36 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 36 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.6.archive.dv_pop.csv'
# ...saved observation population of size 36 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 36 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.6.archive.obs_pop.csv'
# ...resizing current populations to  26
#
#   ---  generation 6 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# WELL_23627__Q            276.5          0      181.457      76.6381      18.2542      282.735
# WELL_23645__Q            158.8          0      159.379      19.0201      93.4796      189.975
# WELL_23653__Q            263.6          0      213.819      41.5316      121.429       308.05
# WELL_23755__Q            794.6          0      447.354       250.16            0      851.903
# WELL_23770__Q            239.9          0      242.569       9.1773      236.005      283.112
# WELL_23816__Q            149.4          0      151.983      6.67362      145.781      171.646
# WELL_23876__Q            197.6          0      180.689      28.5265      91.9496      218.661
# WELL_23934__Q            370.6          0       324.41      70.1077      157.621      441.513
# WELL_24239__Q            271.5          0      256.779      28.4128      201.836      305.552
# WELL_24323__Q            206.4          0      201.909       17.953      159.835      241.201
# WELL_68529__Q            219.9          0      189.022      48.4755      57.4734      243.255
# WELL_69049__Q             37.6          0      36.4982      2.46207       30.512      43.0012
# WELL_69970__Q             62.9          0      63.7121      2.70234      61.1426      74.2588
#
#
#   ---  generation 6 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# WELL_23627__Q            2.4466     1.33037           0           0           0           0
# WELL_23645__Q          -1.82744     -1.1599           0           0      18.107     16.2269
# WELL_23653__Q          -10.0786     -4.9468           0           0    -11.0504    -10.0113
# WELL_23755__Q          -20.2199    -4.73384           0           0           0           0
# WELL_23770__Q                 0           0           0           0           0           0
# WELL_23816__Q         -0.997548   -0.660691           0           0    -22.3174    -18.0761
# WELL_23876__Q           3.05708     1.66375           0           0      37.059      28.726
# WELL_23934__Q           14.3409     4.23346           0           0     50.9733     24.4366
# WELL_24239__Q          -6.58814    -2.63324           0           0    -3.30639    -1.66544
# WELL_24323__Q          0.120466   0.0596277           0           0           0           0
# WELL_68529__Q            3.4852     1.81043           0           0    -17.0857    -42.3042
# WELL_69049__Q         -0.149428   -0.411096           0           0    -2.17247    -7.66584
# WELL_69970__Q         -0.251398   -0.396148           0           0    -4.77896     -8.4788
#
#
#   ---  generation 6 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member 6 as single, 'optimal' point
#    with distance of 0.163247 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# AG_RECEIPTS           maximize 1.220632e+07     125335.4  1.19156e+07 1.239913e+07 1.239913e+07
# FISH_PROB             maximize    0.5917382   0.04835685    0.5084904    0.6717377    0.5084904
#
#
#   ---  generation 6 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# AG_RECEIPTS              2719.59   0.0222753           0           0       88407    0.736479           0           0
# FISH_PROB            0.000525974   0.0888074  -0.0109869    -1.66279           0           0           0           0
#
# ...number of feasible solutions at the end of generation 6: 36
#
#   ---  starting generation  7  ---
# ...generating PSO population of size 26
# ...running population of size  26
# 04/13/26 03:34:41 external run manager calling forward run command(s)
# 04/13/26 03:34:41 calling forward run command: 'python run_pycap_standalone_opt_mou_fish_dollars.py fish_dollars_Tplus10per_0.0_1.0_0.2'
# ...pid: 103500
# ...exit_code: 103500
# ...status: 0
# 04/13/26 03:35:24 forward run command(s) finished, took 42.995 seconds
# ...saved decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.dv_pop.csv'
# ...saved generation-specific decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.7.dv_pop.csv'
# ...saved observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.obs_pop.csv'
# ...saved generation-specific observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.7.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  52
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.summary.csv
# updating archive
# adding 8 non-dominated members to archive
# pareto dominance sorting archive of size 44
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.archive.summary.csv
# resizing archive from 44 to 39 current non-dominated solutions
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.trimmed.archive.summary.csv
# ...saved decision variable population of size 39 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 39 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.7.archive.dv_pop.csv'
# ...saved observation population of size 39 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 39 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.7.archive.obs_pop.csv'
# ...resizing current populations to  26
#
#   ---  generation 7 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# WELL_23627__Q            276.5          0      177.463      83.5775            0      282.735
# WELL_23645__Q            158.8          0      159.379      19.0201      93.4796      189.975
# WELL_23653__Q            263.6          0      208.465      47.9922      100.964       308.05
# WELL_23755__Q            794.6          0       433.74      245.139            0      851.903
# WELL_23770__Q            239.9          0      242.569       9.1773      236.005      283.112
# WELL_23816__Q            149.4          0      151.983      6.67362      145.781      171.646
# WELL_23876__Q            197.6          0      178.651      32.3565      85.4045      218.661
# WELL_23934__Q            370.6          0       311.81       86.962      103.139      441.513
# WELL_24239__Q            271.5          0      258.552      26.2698      202.354      305.552
# WELL_24323__Q            206.4          0      202.055      18.8122      159.835      241.201
# WELL_68529__Q            219.9          0      191.333      48.6055      64.1166      243.255
# WELL_69049__Q             37.6          0      36.4982      2.46207       30.512      43.0012
# WELL_69970__Q             62.9          0      63.7121      2.70234      61.1426      74.2588
#
#
#   ---  generation 7 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# WELL_23627__Q           3.99469     2.20145           0           0     18.2542         100
# WELL_23645__Q                 0           0           0           0           0           0
# WELL_23653__Q           5.35376     2.50388           0           0     20.4657      16.854
# WELL_23755__Q           13.6142     3.04328           0           0           0           0
# WELL_23770__Q                 0           0           0           0           0           0
# WELL_23816__Q                 0           0           0           0           0           0
# WELL_23876__Q           2.03752     1.12764           0           0     6.54511     7.11815
# WELL_23934__Q           12.5991      3.8837           0           0     54.4817     34.5651
# WELL_24239__Q          -1.77307   -0.690505           0           0   -0.517855   -0.256572
# WELL_24323__Q          -0.14582  -0.0722203           0           0           0           0
# WELL_68529__Q           -2.3107    -1.22245           0           0    -6.64327    -11.5589
# WELL_69049__Q                 0           0           0           0           0           0
# WELL_69970__Q                 0           0           0           0           0           0
#
#
#   ---  generation 7 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member 6 as single, 'optimal' point
#    with distance of 0.163247 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# AG_RECEIPTS           maximize 1.219925e+07     132529.2  1.19156e+07 1.239913e+07 1.239913e+07
# FISH_PROB             maximize    0.5944524   0.05014073    0.5084904    0.6717377    0.5084904
#
#
#   ---  generation 7 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# AG_RECEIPTS               7068.4   0.0579077           0           0           0           0           0           0
# FISH_PROB            -0.00271418   -0.458679           0           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 7: 39
#
#   ---  starting generation  8  ---
# ...generating PSO population of size 26
# ...running population of size  26
# 04/13/26 03:35:24 external run manager calling forward run command(s)
# 04/13/26 03:35:24 calling forward run command: 'python run_pycap_standalone_opt_mou_fish_dollars.py fish_dollars_Tplus10per_0.0_1.0_0.2'
# ...pid: 103740
# ...exit_code: 103740
# ...status: 0
# 04/13/26 03:36:07 forward run command(s) finished, took 42.689 seconds
# ...saved decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.dv_pop.csv'
# ...saved generation-specific decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.8.dv_pop.csv'
# ...saved observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.obs_pop.csv'
# ...saved generation-specific observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.8.obs_pop.csv'
# ...pareto dominance sorting combined parent-child populations of size  52
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.summary.csv
# updating archive
# adding 6 non-dominated members to archive
# pareto dominance sorting archive of size 45
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.archive.summary.csv
# resizing archive from 45 to 41 current non-dominated solutions
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.trimmed.archive.summary.csv
# ...saved decision variable population of size 41 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 41 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.8.archive.dv_pop.csv'
# ...saved observation population of size 41 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 41 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.8.archive.obs_pop.csv'
# ...resizing current populations to  26
#
#   ---  generation 8 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# WELL_23627__Q            276.5          0      196.098      77.3973      18.2542      282.735
# WELL_23645__Q            158.8          0      157.778      20.2554      93.4796      189.975
# WELL_23653__Q            263.6          0      207.819      44.3074      108.575       308.05
# WELL_23755__Q            794.6          0      355.107      296.499            0      851.903
# WELL_23770__Q            239.9          0      242.569       9.1773      236.005      283.112
# WELL_23816__Q            149.4          0      151.807      6.80379      144.629      171.646
# WELL_23876__Q            197.6          0      176.686      34.2049      85.4045      218.661
# WELL_23934__Q            370.6          0      285.379      111.125            0      441.513
# WELL_24239__Q            271.5          0      256.706      27.7425      196.487      305.552
# WELL_24323__Q            206.4          0      198.387      23.0606      140.795      241.201
# WELL_68529__Q            219.9          0       190.98      45.1199        81.86      243.255
# WELL_69049__Q             37.6          0      36.2622       2.5211       30.512      43.0012
# WELL_69970__Q             62.9          0      63.7639      2.67316      61.1426      74.2588
#
#
# ...
# ...saved generation-specific observation population of size 123 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.48.archive.obs_pop.csv'
# ...resizing current populations to  26
#
#   ---  generation 48 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# WELL_23627__Q            276.5          0      155.796      105.949            0      282.735
# WELL_23645__Q            158.8          0       146.59      27.3664      79.2174      189.975
# WELL_23653__Q            263.6          0      164.435      100.272            0        263.6
# WELL_23755__Q            794.6          0      301.496      247.693            0      761.173
# WELL_23770__Q            239.9          0      242.368      9.08984        239.9      283.112
# WELL_23816__Q            149.4          0      147.311      9.77189      113.276      167.248
# WELL_23876__Q            197.6          0      92.8231      90.0363            0      218.661
# WELL_23934__Q            370.6          0      167.829      155.614            0      441.513
# WELL_24239__Q            271.5          0      212.288      81.6461            0      292.724
# WELL_24323__Q            206.4          0      187.589       46.116            0      236.729
# WELL_68529__Q            219.9          0      143.348      96.6828            0      242.317
# WELL_69049__Q             37.6          0      34.7575       3.7307      27.8286      43.0012
# WELL_69970__Q             62.9          0      63.2098      2.37289       58.564      74.2588
#
#
#   ---  generation 48 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# WELL_23627__Q           14.5345     8.53313           0           0           0           0
# WELL_23645__Q          0.587297    0.399042           0           0           0           0
# WELL_23653__Q           18.1368     9.93406           0           0           0           0
# WELL_23755__Q           69.8163     18.8026     33.4273      4.2068           0           0
# WELL_23770__Q                 0           0           0           0           0           0
# WELL_23816__Q         0.0342607    0.023252           0           0           0           0
# WELL_23876__Q           15.9169     14.6376           0           0           0           0
# WELL_23934__Q           20.4454     10.8593           0           0           0           0
# WELL_24239__Q           6.86178     3.13109           0           0           0           0
# WELL_24323__Q           2.01743     1.06401           0           0           0           0
# WELL_68529__Q           13.8898     8.83363           0           0           0           0
# WELL_69049__Q          0.169828    0.486232           0           0           0           0
# WELL_69970__Q                 0           0           0           0           0           0
#
#
#   ---  generation 48 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member 6 as single, 'optimal' point
#    with distance of 0.171804 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# AG_RECEIPTS           maximize 1.210034e+07     181283.8 1.179103e+07 1.239913e+07 1.239913e+07
# FISH_PROB             maximize    0.6213674   0.05329596    0.5084904    0.6802949    0.5084904
#
#
#   ---  generation 48 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# AG_RECEIPTS              30711.6    0.253165           0           0           0           0           0           0
# FISH_PROB             -0.0110624     -1.8126           0           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 48: 123
#
#   ---  starting generation  49  ---
# ...generating PSO population of size 26
# ...running population of size  26
# 04/13/26 04:05:35 external run manager calling forward run command(s)
# 04/13/26 04:05:35 calling forward run command: 'python run_pycap_standalone_opt_mou_fish_dollars.py fish_dollars_Tplus10per_0.0_1.0_0.2'
# ...pid: 114004
# ...exit_code: 114004
# ...status: 0
# 04/13/26 04:06:18 forward run command(s) finished, took 42.972 seconds
# ...saved decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.dv_pop.csv'
# ...saved generation-specific decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.49.dv_pop.csv'
# ...saved observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.obs_pop.csv'
# ...saved generation-specific observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.49.obs_pop.csv'
# WARNING: 3 duplicate solutions found, dropping (see rec file for listing)
# WARNING: 3 duplicate solutions found, dropping (see rec file for listing)
# ...pareto dominance sorting combined parent-child populations of size  52
# WARNING: 3 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.summary.csv
# updating archive
# adding 12 non-dominated members to archive
# pareto dominance sorting archive of size 135
# WARNING: 3 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.archive.summary.csv
# resizing archive from 135 to 123 current non-dominated solutions
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.trimmed.archive.summary.csv
# ...saved decision variable population of size 123 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 123 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.49.archive.dv_pop.csv'
# ...saved observation population of size 123 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 123 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.49.archive.obs_pop.csv'
# ...resizing current populations to  26
#
#   ---  generation 49 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# WELL_23627__Q            276.5          0      175.498      100.394            0      282.735
# WELL_23645__Q            158.8          0      145.631      30.8945      51.8079      189.975
# WELL_23653__Q            263.6          0      172.243      91.1274            0        263.6
# WELL_23755__Q            794.6          0      365.572      267.987            0        794.6
# WELL_23770__Q            239.9          0      241.643      9.96702      221.052      283.112
# WELL_23816__Q            149.4          0      146.598      10.4182      113.276      167.248
# WELL_23876__Q            197.6          0      101.461      89.3521            0      218.661
# WELL_23934__Q            370.6          0      194.203      149.685            0      441.513
# WELL_24239__Q            271.5          0      229.263      67.8763            0      292.724
# WELL_24323__Q            206.4          0      178.177      60.5972            0      236.729
# WELL_68529__Q            219.9          0      154.369      93.0121            0      242.317
# WELL_69049__Q             37.6          0      35.6125      3.33881      28.1095      43.0012
# WELL_69970__Q             62.9          0      63.3766      2.18548         62.9      74.2588
#
#
#   ---  generation 49 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# WELL_23627__Q          -19.7026    -12.6464           0           0           0           0
# WELL_23645__Q          0.958895    0.654136           0           0     27.4095     34.6004
# WELL_23653__Q          -7.80792    -4.74835           0           0           0           0
# WELL_23755__Q          -64.0767    -21.2529    -33.4273    -4.39155           0           0
# WELL_23770__Q          0.724924      0.2991           0           0      18.848     7.85662
# WELL_23816__Q           0.71265    0.483773           0           0           0           0
# WELL_23876__Q          -8.63809    -9.30597           0           0           0           0
# WELL_23934__Q          -26.3734    -15.7144           0           0           0           0
# WELL_24239__Q          -16.9754    -7.99643           0           0           0           0
# WELL_24323__Q           9.41142     5.01705           0           0           0           0
# WELL_68529__Q          -11.0212    -7.68844           0           0           0           0
# WELL_69049__Q         -0.855026    -2.45998           0           0   -0.280887    -1.00935
# WELL_69970__Q          -0.16677   -0.263835           0           0    -4.33602     -7.4039
#
#
#   ---  generation 49 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member 6 as single, 'optimal' point
#    with distance of 0.171804 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# AG_RECEIPTS           maximize 1.212062e+07     186783.1 1.179103e+07 1.239913e+07 1.239913e+07
# FISH_PROB             maximize    0.6133151   0.05663718    0.5084904    0.6802949    0.5084904
#
#
#   ---  generation 49 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# AG_RECEIPTS             -20276.7   -0.167572           0           0           0           0           0           0
# FISH_PROB             0.00805227      1.2959           0           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 49: 123
#
#   ---  starting generation  50  ---
# ...generating PSO population of size 26
# ...running population of size  26
# 04/13/26 04:06:18 external run manager calling forward run command(s)
# 04/13/26 04:06:18 calling forward run command: 'python run_pycap_standalone_opt_mou_fish_dollars.py fish_dollars_Tplus10per_0.0_1.0_0.2'
# ...pid: 114269
# ...exit_code: 114269
# ...status: 0
# 04/13/26 04:07:02 forward run command(s) finished, took 43.711 seconds
# ...saved decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.dv_pop.csv'
# ...saved generation-specific decision variable population of size 26 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.50.dv_pop.csv'
# ...saved observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.obs_pop.csv'
# ...saved generation-specific observation population of size 26 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.50.obs_pop.csv'
# WARNING: 2 duplicate solutions found, dropping (see rec file for listing)
# WARNING: 2 duplicate solutions found, dropping (see rec file for listing)
# ...pareto dominance sorting combined parent-child populations of size  52
# WARNING: 2 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.summary.csv
# updating archive
# adding 12 non-dominated members to archive
# pareto dominance sorting archive of size 135
# WARNING: 2 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.archive.summary.csv
# resizing archive from 135 to 125 current non-dominated solutions
# ...wrote pareto summary to fish_dollars_Tplus10per_0.0_1.0_0.2.pareto.trimmed.archive.summary.csv
# ...saved decision variable population of size 125 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 125 X 13 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.50.archive.dv_pop.csv'
# ...saved observation population of size 125 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.archive.obs_pop.csv'
# ...saved generation-specific observation population of size 125 X 332 to 'fish_dollars_Tplus10per_0.0_1.0_0.2.50.archive.obs_pop.csv'
# ...resizing current populations to  26
#
#   ---  generation 50 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# WELL_23627__Q            276.5          0      165.216      106.072            0      282.735
# WELL_23645__Q            158.8          0      148.852      28.9741      51.8079      189.975
# WELL_23653__Q            263.6          0      168.153      97.0005            0        263.6
# WELL_23755__Q            794.6          0      371.618      259.031            0        794.6
# WELL_23770__Q            239.9          0      241.643      9.96702      221.052      283.112
# WELL_23816__Q            149.4          0       147.25      10.1527      113.276      167.248
# WELL_23876__Q            197.6          0      109.378       88.533            0      218.661
# WELL_23934__Q            370.6          0      200.257      149.813            0      441.513
# WELL_24239__Q            271.5          0      235.322      64.1902            0      292.724
# WELL_24323__Q            206.4          0      184.692      56.6573            0      236.729
# WELL_68529__Q            219.9          0       158.93      88.7172            0      242.317
# WELL_69049__Q             37.6          0      35.1021      3.93437      26.6534      43.0012
# WELL_69970__Q             62.9          0      63.3766      2.18548         62.9      74.2588
#
#
#   ---  generation 50 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# WELL_23627__Q           10.2819     5.85866           0           0           0           0
# WELL_23645__Q          -3.22139    -2.21203           0           0           0           0
# WELL_23653__Q           4.08946     2.37424           0           0           0           0
# WELL_23755__Q          -6.04542    -1.65369           0           0           0           0
# WELL_23770__Q                 0           0           0           0           0           0
# WELL_23816__Q         -0.651392   -0.444338           0           0           0           0
# WELL_23876__Q          -7.91706    -7.80305           0           0           0           0
# WELL_23934__Q          -6.05419    -3.11746           0           0           0           0
# WELL_24239__Q          -6.05898    -2.64281           0           0           0           0
# WELL_24323__Q          -6.51461    -3.65625           0           0           0           0
# WELL_68529__Q          -4.56075    -2.95444           0           0           0           0
# WELL_69049__Q          0.510395     1.43319           0           0     1.45608     5.18002
# WELL_69970__Q                 0           0           0           0           0           0
#
#
#   ---  generation 50 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member 6 as single, 'optimal' point
#    with distance of 0.171804 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# AG_RECEIPTS           maximize 1.212778e+07       172803 1.179103e+07 1.239913e+07 1.239913e+07
# FISH_PROB             maximize    0.6141217   0.05330248    0.5084904    0.6802949    0.5084904
#
#
#   ---  generation 50 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# AG_RECEIPTS              -7162.8   -0.059096           0           0           0           0           0           0
# FISH_PROB           -0.000806595   -0.131514           0           0           0           0           0           0
#
# ...number of feasible solutions at the end of generation 50: 125
#
#
# pestpp-mou analysis complete...
# started at 04/13/26 03:29:09
# finished at 04/13/26 04:07:03
# took 37.8833 minutes

# %% [markdown]
# #### Finally, compress the results to save diskspace and delete the original files. Postprocessing will only work with the compressed files.

# %%
# zip up all the results
for cf in run_path.glob('*.csv'):
    if "_pop" in cf.name or "archive" in cf.name or "summary" in cf.name:
        with zipfile.ZipFile(cf.with_suffix('.csv.zip'), 'w', compression=zipfile.ZIP_DEFLATED, compresslevel=9) as ofp:
            ofp.write(cf, arcname=cf.name)
        cf.unlink()
